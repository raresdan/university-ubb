# %%
plot(sin(x),0,1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
from sage.plot.line import Line
N=200
r=1
x=zero_vector(RR,N+1),
x[0]=0.5
for n in range(1,N):
    x[n] =r*(x[n-1])*(1-x[n-1])
l = line(Line(rang(N),X,{}, color ='blue', marker='0'))
show(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-2eec2191f9f7> in <module>
#       3 r=Integer(1)
#       4 x=zero_vector(RR,N+Integer(1)),
# ----> 5 x[Integer(0)]=RealNumber('0.5')
#       6 for n in range(Integer(1),N):
#       7     x[n] =r*(x[n-Integer(1)])*(Integer(1)-x[n-Integer(1)])
#
# TypeError: 'tuple' object does not support item assignment

# %%
from sage.plot.line import Line
N=40
r=4
x=zero_vector(RR,N+1) #RR-real numbers
x[0]=0.67
y=zero_vector(RR,N+1)
y[0]=0.670001
for n in range(1,N):
    x[n]=r*x[n-1]*(1-x[n-1])
    y[n]=r*y[n-1]*(1-y[n-1])
    
lx=line(Line(range(N),x,{}),color='blue',marker='o')
ly=line(Line(range(N),y,{}),color='red',marker='o')
show(lx + ly)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
from sage.plot.line import Line
N=11
r=1/(N-1)
x=zero_vector(RR,N) #RR-real numbers
y=zero_vector(RR,N)
y[0]=1 #euler method
ye=zero_vector(RR,N)
ye[0]=1
for k in range(1,N):
    x[k]=x[k-1]+r
    y[k]=y[k-1]+r*2*x[k-1]*y[k-1]
    ye[k]=exp(x[k]^2)
    
ly=line(Line(range(N),y,{}),color='blue',marker='o')
lye=line(Line(range(N),ye,{}),color='red',marker='o')
show(ly+lye)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
x,y = var('x y')
f = x^2+y^2
PDF = plot_vector_field((x,y),(x,0,2.2),(y,0,9))
h=0.1
x=srange(0,2,h) 
ye = desolve_odeint(f,0,x,y)
N=21
y=zero_vector(RR,N)
y[0] = 0
for k in range(1,N):
	y[k] = y[k-1] + h*(x[k-1]^2+y[k-1]^2)
ly=line(Line(x,ye,{}),color='red',marker='o')
show(PDF + ly + line(zip(x,ye)))
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
from sage.plot.line import Line
h=0.1
N=11
a=22
x=zero_vector(RR,N)
y=zero_vector(RR,N)
yy=zero_vector(RR,N)
y[0]=1
yy[0]=1
for k in range(1,N):
    x[k]=x[k-1]+h
    y[k]=y[k-1]+h*a*y[k-1]
    yy[k]=yy[k-1]+h/2*a*yy[k-1]+h/2*h*a*(yy[k-1]+h*a*yy[k-1])
ly=line(Line(x,y,{}),color='red',marker='o')
lyy=line(Line(x,y,{}),color='blue',marker='o')
show(lyy+ly)
# Out:
# Graphics object consisting of 2 graphics primitives
