# %%
t = var('t')
x = function('x')(t)
desolve(diff(x,t)+x==2/sqrt(pi)*e^(-t^2-t), x)
# Out:
# (_C + erf(t))*e^(-t)

# %%
integral(sin(t),t)
# Out:
# -cos(t)

# %%
t = var('t')
x = function('x')(t)
sol = desolve(diff(x,t,2)+3*diff(x,t)+x == 1, x)
limit(sol,t=infinity)
sol
# Out:
# _K2*e^(-1/2*t*(sqrt(5) + 3)) + _K1*e^(1/2*t*(sqrt(5) - 3)) + 1

# %%
t = var('t')
x = function('x')(t)
sol = desolve(diff(x,t,2)+4*x == 1, x, ics =[0,5/4,0])
limit(sol,t=infinity)
sol
# Out:
# cos(2*t) + 1/4

# %%
t = var('t')
x = function('x')(t)
sol = desolve(diff(x,t) == 13*x + t^3, x)
limit(sol,t=infinity)
sol
sol.subs(_C=0)
# Out:
# -1/13*t^3 - 3/169*t^2 - 6/2197*t - 6/28561

# %%
f=piecewise([((0,pi),t),((pi,infinity),pi*e^(pi-t))])
f
# Out:
# piecewise(t|-->t on (0, pi), t|-->pi*e^(pi - t) on (pi, +oo); t)

# %%
plot(f,0,5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t = var('t')
x = function('x')(t)
sol = desolve(diff(x,t,2)+x == t, x, ics =[0,0,1])
limit(sol,t=infinity)
sol
# Out:
# t

# %%
t = var('t')
x = function('x')(t)
sol = desolve(diff(x,t,2)+x == pi*e^(pi-t), x, ics =[pi,sol.subs(t=pi),diff(sol,t).subs(t=pi)])
limit(sol,t=infinity)
sol
# Out:
# -1/2*pi*cos(t) + 1/2*pi*e^(pi - t) - 1/2*(pi + 2)*sin(t)

# %%
t = var('t')
w = var('w')
x = function('x')(t)
solve = desolve(diff(x,t,2) + x == cos(w*t), x, ics = [0,0,0], ivar = t)
sol1 = desolve(diff(x,t,2) + x == cos(t), x, ics = [0,0,0], ivar = t)
sol1
# Out:
# 1/2*t*sin(t)

# %%
limit(solve,w=1)-sol1
# Out:
# 0

# %%
plot(sol1,0,5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t = var('t')
x = function('x')(t)
sol1 = desolve(diff(x,t,2)+x == t, x, ics =[0,5,0])
sol2 = desolve(diff(x,t,2)+x == pi-t, x, ics =[pi/2,sol1(pi/2),diff(sol1,t).subs(t=pi/2)])
sol3 = desolve(diff(x,t,2)+x == 0, x, ics =[pi,sol2(pi),diff(sol2,t).subs(t=pi)])
f = piecewise([((0, pi/2),sol1), ((pi/2, pi),sol2), ((pi,infinity), sol3)])
plot(f,0,10)
# NU MERGE BA
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/plot/plot.py in generate_plot_points(f, xrange, plot_points, adaptive_tolerance, adaptive_recursion, randomize, initial_points, excluded)
#    3956         try:
# -> 3957             data[i] = (float(xi), float(f(xi)))
#    3958             if str(data[i][1]) in ['nan', 'NaN', 'inf', '-inf']:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/ext/interpreters/wrapper_py.pyx in sage.ext.interpreters.wrapper_py.Wrapper_py.__call__ (build/cythonized/sage/ext/interpreters/wrapper_py.c:2040)()
#      67                 Py_CLEAR(self._stack[i])
# ---> 68             raise
#      69
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/ext/interpreters/wrapper_py.pyx in sage.ext.interpreters.wrapper_py.Wrapper_py.__call__ (build/cythonized/sage/ext/interpreters/wrapper_py.c:1974)()
#      59         try:
# ---> 60             return interp_py((<PyTupleObject*>args).ob_item
#      61                 , self._constants
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression._eval_on_operands.new_f (build/cythonized/sage/symbolic/expression.cpp:69807)()
#   12964         new_args.extend(args)
# > 12965         return f(ex, *new_args, **kwds)
#   12966     return new_f
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/functions/piecewise.py in __call__(self, parameters, variable, value, **kwds)
#     468                 substitution[variable] = value
# --> 469             return self.subs(substitution)
#     470
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.substitute (build/cythonized/sage/symbolic/expression.cpp:31953)()
#    5543                                   (<Expression>self.coerce_in(v))._gobj))
# -> 5544         res = self._gobj.subs_map(smap, 0)
#    5545         return new_Expression_from_GEx(self._parent, res)
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/functions/piecewise.py in _subs_(self, subs_map, options, parameters, x)
#     230                 return subs_map.apply_to(func, 0)
# --> 231         raise ValueError('point {} is not in the domain'.format(point))
#     232
#
# ValueError: point 0.0 is not in the domain
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-47-3eb18b9fcc74> in <module>
#       5 sol3 = desolve(diff(x,t,Integer(2))+x == Integer(0), x, ics =[pi,sol2(pi),diff(sol2,t).subs(t=pi)])
#       6 f = piecewise([((Integer(0), pi/Integer(2)),sol1), ((pi/Integer(2), pi),sol2), ((pi,infinity), sol3)])
# ----> 7 plot(f,Integer(0),Integer(10))
#       8 # NU MERGE BA
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/misc/decorators.py in wrapper(*args, **kwds)
#     489                 options['__original_opts'] = kwds
#     490             options.update(kwds)
# --> 491             return func(*args, **options)
#     492
#     493         #Add the options specified by @options to the signature of the wrapped
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/plot/plot.py in plot(funcs, *args, **kwds)
#    1955
#    1956     if hasattr(funcs, 'plot'):
# -> 1957         G = funcs.plot(*args, **original_opts)
#    1958
#    1959         # If we have extra keywords already set, then update them
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.plot (build/cythonized/sage/symbolic/expression.cpp:65951)()
#   12306             except NotImplementedError:
#   12307                 return self.function(param)
# > 12308         return plot(f, *args, **kwds)
#   12309
#   12310     def _plot_fast_callable(self, *vars):
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/misc/decorators.py in wrapper(*args, **kwds)
#     489                 options['__original_opts'] = kwds
#     490             options.update(kwds)
# --> 491             return func(*args, **options)
#     492
#     493         #Add the options specified by @options to the signature of the wrapped
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/plot/plot.py in plot(funcs, *args, **kwds)
#    1980             xmax = args[1]
#    1981             args = args[2:]
# -> 1982             G = _plot(funcs, (xmin, xmax), *args, **kwds)
#    1983         elif n == 3:
#    1984         # if there are three extra args, then pull them out and pass them as a tuple
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/plot/plot.py in _plot(funcs, xrange, parametric, polar, fill, label, randomize, **options)
#    2299             adaptive_tolerance, adaptive_recursion,
#    2300             randomize, initial_points,
# -> 2301             excluded=True)
#    2302
#    2303     excluded_points += extra_excluded
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/plot/plot.py in generate_plot_points(f, xrange, plot_points, adaptive_tolerance, adaptive_recursion, randomize, initial_points, excluded)
#    3969                     xj = xi + delta*j/100.0
#    3970                     try:
# -> 3971                         data[i] = (float(xj), float(f(xj)))
#    3972                         # nan != nan
#    3973                         if data[i][1] != data[i][1]:
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/ext/interpreters/wrapper_py.pyx in sage.ext.interpreters.wrapper_py.Wrapper_py.__call__ (build/cythonized/sage/ext/interpreters/wrapper_py.c:2040)()
#      66             for i in range(self._n_stack):
#      67                 Py_CLEAR(self._stack[i])
# ---> 68             raise
#      69
#      70
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/ext/interpreters/wrapper_py.pyx in sage.ext.interpreters.wrapper_py.Wrapper_py.__call__ (build/cythonized/sage/ext/interpreters/wrapper_py.c:1974)()
#      58         if self._n_args != len(args): raise ValueError
#      59         try:
# ---> 60             return interp_py((<PyTupleObject*>args).ob_item
#      61                 , self._constants
#      62                 , self._stack
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression._eval_on_operands.new_f (build/cythonized/sage/symbolic/expression.cpp:69807)()
#   12963         new_args = list(ex._unpack_operands())
#   12964         new_args.extend(args)
# > 12965         return f(ex, *new_args, **kwds)
#   12966     return new_f
#   12967
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/functions/piecewise.py in __call__(self, parameters, variable, value, **kwds)
#     467             if value is not None:
#     468                 substitution[variable] = value
# --> 469             return self.subs(substitution)
#     470
#     471         def _fast_float_(self, *args):
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.substitute (build/cythonized/sage/symbolic/expression.cpp:31953)()
#    5542             smap.insert(make_pair((<Expression>self.coerce_in(k))._gobj,
#    5543                                   (<Expression>self.coerce_in(v))._gobj))
# -> 5544         res = self._gobj.subs_map(smap, 0)
#    5545         return new_Expression_from_GEx(self._parent, res)
#    5546
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/functions/piecewise.py in _subs_(self, subs_map, options, parameters, x)
#     212         """
#     213         point = subs_map.apply_to(x, 0)
# --> 214         if point == x:
#     215             # substitution only in auxiliary variables
#     216             new_params = []
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/symbolic/expression.pyx in sage.symbolic.expression.Expression.__nonzero__ (build/cythonized/sage/symbolic/expression.cpp:20899)()
#    3216             from sage.symbolic.relation import test_relation_maxima
#    3217             if self.variables():
# -> 3218                 return test_relation_maxima(self)
#    3219             else:
#    3220                 return False
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/symbolic/relation.py in test_relation_maxima(relation)
#     498     if relation.operator() == operator.eq: # operator is equality
#     499         try:
# --> 500             s = m.parent()._eval_line('is (equal(%s,%s))'%(repr(m.lhs()),repr(m.rhs())))
#     501         except TypeError:
#     502             raise ValueError("unable to evaluate the predicate '%s'" % repr(relation))
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/interfaces/maxima_lib.py in _eval_line(self, line, locals, reformat, **kwds)
#     451                     line = line[ind_semi+1:]
#     452                 if statement:
# --> 453                     result = ((result + '\n') if result else '') + max_to_string(maxima_eval("#$%s$"%statement))
#     454             else:
#     455                 statement = line[:ind_dollar]
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/libs/ecl.pyx in sage.libs.ecl.EclObject.__call__ (build/cythonized/sage/libs/ecl.c:8623)()
#     852         """
#     853         lispargs = EclObject(list(args))
# --> 854         return ecl_wrap(ecl_safe_apply(self.obj,(<EclObject>lispargs).obj))
#     855
#     856     def __richcmp__(left, right, int op):
#
# /opt/sagemath-9.3/local/lib/python3.7/site-packages/sage/libs/ecl.pyx in sage.libs.ecl.ecl_safe_apply (build/cythonized/sage/libs/ecl.c:5905)()
#     363
#     364     if error != NULL:
# --> 365         raise RuntimeError("ECL says: {}".format(
#     366             ecl_string_to_python(error)))
#     367     else:
#
# RuntimeError: ECL says: C-STACK overflow at size 2080768. Stack can probably be resized.
# Proceed with caution.
